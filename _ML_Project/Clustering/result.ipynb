# %% [markdown]
# 0 track_expenditure -> payment app(0.62)
# 1 unplanned purchases (0.80),peer_influemce ->5(0.8)
# 2 not special traits
# 3 price_importance -> very important(0.7), brand_importance-> very importance(0.9) utility_importance->very important(0.9), majorly spend on fashion(0.9),spend on buget entertainmnet(0.9)
# 4 spend on subscription(1.0),spend not on entertainment(0.93)
# 5 medium sized city (0.79)
# 6 peer impotance-> slighlty importnt(0.73), majorly spend on travel(0.73)
# 7 brand importance ->slighlty important(0.88)
